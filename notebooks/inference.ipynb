# %% [markdown]
# # Setting Up for Inference

# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/MasterCourse_Project/Wildflower_Recognizer
# Out:
# /content/drive/My Drive/MasterCourse_Project/Wildflower_Recognizer

# %%
version = 1
img_path = 'test_images'
model_path = f'models/Wildflower-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# # Inference 1
# **Target:** Alpine Aster

# %%
img = Image.open(f'{img_path}/unknown_00.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/unknown_00.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Alpine Aster',
#  tensor(0),
#  tensor([9.9940e-01, 2.5439e-06, 8.0392e-05, 2.0223e-07, 1.3890e-05, 3.9858e-06,
#          3.2209e-06, 2.1286e-05, 4.8370e-06, 1.6818e-05, 1.5990e-06, 2.7747e-06,
#          2.8211e-04, 4.9869e-06, 5.9433e-07, 1.3245e-05, 9.0984e-06, 7.0871e-06,
#          4.1472e-05, 1.6202e-05, 6.8406e-07, 4.3286e-06, 1.5177e-06, 4.4828e-06,
#          6.2424e-05]))

# %% [markdown]
# # Inference 2
# **Target:** Pitcher Plant

# %%
img = Image.open(f'{img_path}/unknown_01.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown_01.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Pitcher Plant',
#  tensor(14),
#  tensor([7.5318e-10, 3.9425e-08, 3.8461e-09, 4.8195e-08, 3.9650e-08, 1.6045e-07,
#          4.3857e-07, 3.9102e-07, 4.4870e-08, 1.2283e-10, 7.9548e-09, 2.4402e-05,
#          6.6180e-06, 6.8829e-07, 9.9996e-01, 1.1888e-07, 2.1023e-09, 2.5293e-07,
#          2.0015e-08, 2.7887e-07, 1.1779e-06, 6.6882e-06, 7.5520e-09, 8.0385e-08,
# ...

# %% [markdown]
# # Inference 3
# **Target:** Ocotillo

# %%
img = Image.open(f'{img_path}/unknown_02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/unknown_02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Ocotillo',
#  tensor(13),
#  tensor([4.0779e-09, 1.2927e-08, 7.0155e-09, 3.0773e-10, 1.8449e-09, 4.6569e-09,
#          1.3969e-07, 3.3999e-09, 2.0422e-07, 1.5732e-06, 1.1267e-05, 1.5417e-08,
#          3.8597e-08, 9.9997e-01, 1.0314e-08, 5.8993e-08, 6.0007e-10, 1.5558e-05,
#          4.3879e-09, 1.5328e-06, 6.2091e-07, 1.9556e-07, 4.0438e-10, 1.4565e-07,
#          1.0629e-08]))

# %% [markdown]
# # Inference 4
# **Target:** Black-eyed susan

# %%
img = Image.open(f'{img_path}/unknown_03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/unknown_03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Black-eyed Susan',
#  tensor(4),
#  tensor([2.9386e-04, 1.5894e-05, 5.7101e-06, 2.7420e-06, 9.8839e-01, 1.2188e-06,
#          1.2713e-05, 4.8732e-04, 1.3851e-04, 8.4321e-03, 4.3909e-06, 4.3237e-06,
#          5.3822e-06, 4.1005e-06, 2.5736e-05, 1.2532e-04, 1.4025e-06, 4.0212e-05,
#          2.4558e-05, 2.5604e-05, 1.6178e-03, 1.0190e-04, 2.0548e-04, 9.9744e-06,
# ...

# %% [markdown]
# # Inference 5
# **Target:** Daisy

# %%
img = Image.open(f'{img_path}/unknown_04.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x113>

# %%
model.predict(f'{img_path}/unknown_04.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Daisy',
#  tensor(7),
#  tensor([6.5138e-06, 3.4496e-07, 4.9689e-06, 5.5443e-07, 9.3798e-08, 2.3585e-06,
#          3.1240e-08, 9.9992e-01, 2.3674e-05, 1.0100e-05, 4.0378e-08, 1.2260e-07,
#          8.9066e-09, 4.3780e-08, 3.4988e-07, 9.2925e-08, 9.6513e-08, 1.4360e-07,
#          1.4653e-06, 3.7720e-08, 2.0728e-05, 2.1317e-08, 3.3587e-06, 9.5837e-07,
#          2.4662e-08]))

# %% [markdown]
# # Version 1

# %% [markdown]
# ## Inference 6
# **Target:** beach evening primrose

# %%
img = Image.open(f'{img_path}/unknown_05.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/unknown_05.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Beach Evening Primrose',
#  tensor(2),
#  tensor([3.9697e-08, 1.2276e-05, 9.9974e-01, 5.1393e-07, 3.3475e-05, 1.0289e-05,
#          1.5033e-05, 2.9759e-06, 6.5607e-07, 3.3987e-07, 1.3629e-06, 4.2147e-07,
#          4.1040e-07, 2.6744e-07, 2.8608e-05, 1.0909e-08, 8.1968e-05, 1.0231e-05,
#          4.9651e-05, 8.1526e-08, 3.3101e-06, 5.7978e-07, 6.3169e-06, 4.0398e-06,
# ...

# %% [markdown]
# ## Inference 7
# **Target:** beach morning glory

# %%
img = Image.open(f'{img_path}/unknown_06.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown_06.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Beach Morning Glory',
#  tensor(3),
#  tensor([1.0605e-06, 9.1241e-06, 1.9006e-05, 9.9816e-01, 3.8408e-07, 6.7849e-07,
#          3.5111e-06, 1.2409e-07, 3.7069e-06, 4.4281e-07, 5.6456e-06, 3.6089e-06,
#          5.8922e-07, 6.3539e-07, 1.6473e-03, 1.1404e-06, 1.8112e-05, 8.5250e-06,
#          2.0440e-07, 2.2356e-05, 1.9385e-06, 2.0421e-05, 1.9938e-05, 3.2422e-07,
# ...

# %% [markdown]
# ## Inference 8
# **Target:** seaside goldenrod

# %%
img = Image.open(f'{img_path}/unknown_07.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(f'{img_path}/unknown_07.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Seaside Goldenrod',
#  tensor(19),
#  tensor([1.5650e-08, 3.3458e-10, 1.3478e-08, 7.9875e-10, 1.5745e-07, 2.0792e-09,
#          3.8642e-09, 2.9054e-08, 7.4437e-06, 2.3868e-05, 2.4115e-08, 6.3390e-09,
#          2.4562e-07, 2.9783e-09, 9.9848e-10, 6.7106e-08, 7.7727e-09, 9.5735e-09,
#          9.1318e-08, 9.9997e-01, 1.9116e-08, 3.2394e-08, 2.9011e-09, 6.5823e-09,
# ...

# %% [markdown]
# # Version 2

# %% [markdown]
# ## Inference 9
# **Target:** Queen Anne's Lace

# %%
img = Image.open(f'{img_path}/unknown_08.jpg')
img.to_thumb(128,128)

# %%
model.predict(f'{img_path}/unknown_08.jpg')

# %% [markdown]
# ## Inference 10
# **Target:** Alpine Forget-me-not

# %%
img = Image.open(f'{img_path}/unknown_09.jpg')
img.to_thumb(128,128)

# %%
model.predict(f'{img_path}/unknown_09.jpg')

# %% [markdown]
# ## Inference 11
# **Target:** prickly Pear

# %%
img = Image.open(f'{img_path}/unknown_10.jpg')
img.to_thumb(128,128)

# %%
model.predict(f'{img_path}/unknown_10.jpg')
